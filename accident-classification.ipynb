# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from time import perf_counter 
import os
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.utils import plot_model

# %%
## Defining batch specfications
batch_size = 50
img_height = 750
img_width = 750

# %%
## loading training set
training_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/train',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 791 files belonging to 2 classes.

# %%
## loading validation dataset
validation_data =  tf.keras.preprocessing.image_dataset_from_directory(
    'data/val',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 98 files belonging to 2 classes.

# %%
## loading testing dataset
testing_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/test',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 100 files belonging to 2 classes.

# %%
testing_data
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 750, 750, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = training_data.class_names
class_names
# Out:
# ['Accident', 'Non Accident']

# %%
## Configuring dataset for performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_data = training_data.cache().prefetch(buffer_size=AUTOTUNE)
testing_data = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'), # Conv2D(f_size, filter_size, activation) # relu, sigmoid, softmax
  layers.MaxPooling2D(), # MaxPooling
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(len(class_names), activation= 'softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model = tf.keras.models.Sequential([
    layers.Conv2D(64, 3, activation='relu', input_shape=(img_height, img_width, 3)),  # Adjust input shape
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(256, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(512, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.5),  # Add dropout for regularization
    
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),  # Add dropout for regularization
    
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build((None, 250, 250, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 250, 250, 3)       12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 124, 124, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 61, 61, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 29, 29, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 22541134 (85.99 MB)
# Trainable params: 22541128 (85.99 MB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________

# %%
pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in c:\users\satya\appdata\roaming\python\python39\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
## lets train our CNN
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(training_data, validation_data=validation_data, epochs = 20, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 8/8 [==============================] - ETA: 0s - loss: 2.8472 - accuracy: 0.4678
# Epoch 1: val_accuracy improved from -inf to 0.53061, saving model to model_weights.h5
# C:\Users\satya\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 61s 7s/step - loss: 2.8472 - accuracy: 0.4678 - val_loss: 0.6927 - val_accuracy: 0.5306
# Epoch 2/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6858 - accuracy: 0.5322
# Epoch 2: val_accuracy did not improve from 0.53061
# 8/8 [==============================] - 49s 6s/step - loss: 0.6858 - accuracy: 0.5322 - val_loss: 0.6923 - val_accuracy: 0.4694
# Epoch 3/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6486 - accuracy: 0.6296
# Epoch 3: val_accuracy did not improve from 0.53061
# 8/8 [==============================] - 59s 7s/step - loss: 0.6486 - accuracy: 0.6296 - val_loss: 0.7190 - val_accuracy: 0.4694
# Epoch 4/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.6473
# Epoch 4: val_accuracy did not improve from 0.53061
# 8/8 [==============================] - 56s 7s/step - loss: 0.6240 - accuracy: 0.6473 - val_loss: 0.6844 - val_accuracy: 0.5306
# Epoch 5/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.6738
# Epoch 5: val_accuracy did not improve from 0.53061
# 8/8 [==============================] - 56s 7s/step - loss: 0.5983 - accuracy: 0.6738 - val_loss: 0.7713 - val_accuracy: 0.4694
# Epoch 6/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5640 - accuracy: 0.6903
# Epoch 6: val_accuracy improved from 0.53061 to 0.69388, saving model to model_weights.h5
# 8/8 [==============================] - 57s 7s/step - loss: 0.5640 - accuracy: 0.6903 - val_loss: 0.5963 - val_accuracy: 0.6939
# Epoch 7/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5339 - accuracy: 0.7472
# Epoch 7: val_accuracy improved from 0.69388 to 0.73469, saving model to model_weights.h5
# 8/8 [==============================] - 52s 7s/step - loss: 0.5339 - accuracy: 0.7472 - val_loss: 0.5745 - val_accuracy: 0.7347
# Epoch 8/20
# 8/8 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.7547
# Epoch 8: val_accuracy improved from 0.73469 to 0.75510, saving model to model_weights.h5
# 8/8 [==============================] - 54s 7s/step - loss: 0.4977 - accuracy: 0.7547 - val_loss: 0.5259 - val_accuracy: 0.7551
# Epoch 9/20
# 8/8 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.7851
# Epoch 9: val_accuracy improved from 0.75510 to 0.77551, saving model to model_weights.h5
# 8/8 [==============================] - 56s 7s/step - loss: 0.4412 - accuracy: 0.7851 - val_loss: 0.4807 - val_accuracy: 0.7755
# Epoch 10/20
# 8/8 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8116
# Epoch 10: val_accuracy improved from 0.77551 to 0.79592, saving model to model_weights.h5
# 8/8 [==============================] - 60s 7s/step - loss: 0.3882 - accuracy: 0.8116 - val_loss: 0.4416 - val_accuracy: 0.7959
# Epoch 11/20
# 8/8 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8470
# Epoch 11: val_accuracy did not improve from 0.79592
# 8/8 [==============================] - 56s 7s/step - loss: 0.3075 - accuracy: 0.8470 - val_loss: 0.5434 - val_accuracy: 0.7041
# Epoch 12/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9027
# Epoch 12: val_accuracy did not improve from 0.79592
# 8/8 [==============================] - 55s 7s/step - loss: 0.2403 - accuracy: 0.9027 - val_loss: 0.5191 - val_accuracy: 0.7755
# Epoch 13/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9241
# Epoch 13: val_accuracy improved from 0.79592 to 0.86735, saving model to model_weights.h5
# 8/8 [==============================] - 55s 7s/step - loss: 0.1885 - accuracy: 0.9241 - val_loss: 0.3280 - val_accuracy: 0.8673
# Epoch 14/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9355
# Epoch 14: val_accuracy did not improve from 0.86735
# 8/8 [==============================] - 55s 7s/step - loss: 0.1544 - accuracy: 0.9355 - val_loss: 0.4129 - val_accuracy: 0.8571
# Epoch 15/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9305
# Epoch 15: val_accuracy did not improve from 0.86735
# 8/8 [==============================] - 54s 7s/step - loss: 0.1814 - accuracy: 0.9305 - val_loss: 0.4470 - val_accuracy: 0.8571
# Epoch 16/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9305
# Epoch 16: val_accuracy did not improve from 0.86735
# 8/8 [==============================] - 56s 7s/step - loss: 0.1729 - accuracy: 0.9305 - val_loss: 0.3223 - val_accuracy: 0.8571
# Epoch 17/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9583
# Epoch 17: val_accuracy did not improve from 0.86735
# 8/8 [==============================] - 55s 7s/step - loss: 0.1055 - accuracy: 0.9583 - val_loss: 0.3882 - val_accuracy: 0.8469
# Epoch 18/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9709
# Epoch 18: val_accuracy improved from 0.86735 to 0.88776, saving model to model_weights.h5
# 8/8 [==============================] - 57s 7s/step - loss: 0.0803 - accuracy: 0.9709 - val_loss: 0.3925 - val_accuracy: 0.8878
# Epoch 19/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9684
# Epoch 19: val_accuracy improved from 0.88776 to 0.90816, saving model to model_weights.h5
# 8/8 [==============================] - 63s 8s/step - loss: 0.0918 - accuracy: 0.9684 - val_loss: 0.2454 - val_accuracy: 0.9082
# Epoch 20/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9722
# Epoch 20: val_accuracy did not improve from 0.90816
# 8/8 [==============================] - 57s 7s/step - loss: 0.0694 - accuracy: 0.9722 - val_loss: 0.3885 - val_accuracy: 0.8265

# %%
###### serialize model structure to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
## stats on training data
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.grid(True)
plt.legend()

# %%
## stats on training data
plt.plot(history.history['val_loss'], label = 'validation loss')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.grid(True)
plt.legend()

# %%
## lets vizualize results on testing data
AccuracyVector = []
plt.figure(figsize=(30, 30))
for images, labels in testing_data.take(1):
    predictions = model.predict(images)
    predlabel = []
    prdlbl = []
    
    for mem in predictions:
        predlabel.append(class_names[np.argmax(mem)])
        prdlbl.append(np.argmax(mem))
    
    AccuracyVector = np.array(prdlbl) == labels
    for i in range(40):
        ax = plt.subplot(10, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title('Pred: '+ predlabel[i]+' actl:'+class_names[labels[i]] )
        plt.axis('off')
        plt.grid(True)
# Out:
# 4/4 [==============================] - 2s 258ms/step

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\satya\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: opencv-python in c:\users\satya\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 3)) (4.8.1.78)
# Requirement already satisfied: tensorflow in c:\users\satya\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: keras in c:\users\satya\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 5)) (2.13.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow->-r requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (4.21.12)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (23.5.26)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.57.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (16.0.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (61.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.31.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\satya\appdata\roaming\python\python39\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.22.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (4.2.2)
# Requirement already satisfied: urllib3<2.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.26.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\satya\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 4)) (3.0.4)Note: you may need to restart the kernel to use updated packages.
